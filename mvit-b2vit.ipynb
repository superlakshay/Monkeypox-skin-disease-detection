# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, random_split, Subset, TensorDataset
from transformers import ViTModel
import os
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np
import cv2
from transformers.models.vit.modeling_vit import ViTEncoder

# Paths and parameters
folder_path = "/kaggle/input/monkeypox-skin-lesion-dataset/Augmented Images/Augmented Images"
subfolders = ['Monkeypox_augmented', 'Others_augmented']
image_size = (224, 224)
batch_size = 16
epochs = 30
learning_rate = 0.0001
gamma = 0.5  # Weight for combining deep and broad features

# Image transformations
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load dataset
data = []
labels = []
label_map = {subfolder: idx for idx, subfolder in enumerate(subfolders)}

for subfolder in subfolders:
    subfolder_path = os.path.join(folder_path, subfolder)
    for filename in os.listdir(subfolder_path):
        img_path = os.path.join(subfolder_path, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, image_size)
            data.append(img)
            labels.append(label_map[subfolder])

data = np.array(data).astype("float32")
labels = np.array(labels)

# Create PyTorch datasets
data = torch.tensor(data).permute(0, 3, 1, 2) / 255.0  # Normalize
labels = torch.tensor(labels)

# Create a TensorDataset
dataset = TensorDataset(data, labels)

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Broad Attention Mechanism
class BroadAttention(nn.Module):
    def __init__(self, hidden_size, num_layers):
        super(BroadAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.attention = nn.MultiheadAttention(embed_dim=hidden_size, num_heads=8)
        self.pool = nn.AdaptiveAvgPool1d(1)

    def forward(self, queries, keys, values):
        queries = torch.cat(queries, dim=1)
        keys = torch.cat(keys, dim=1)
        values = torch.cat(values, dim=1)
        attention_output, _ = self.attention(queries, keys, values)
        pooled_output = self.pool(attention_output.permute(0, 2, 1)).squeeze(-1)
        return pooled_output

# MVIT-Integrated B2VIT Model
class B2MVITNet(nn.Module):
    def __init__(self, vit_model_name, num_classes, gamma=0.5):
        super(B2MVITNet, self).__init__()
        self.vit = ViTModel.from_pretrained(vit_model_name, output_attentions=True)
        self.hidden_size = self.vit.config.hidden_size
        self.num_layers = len(self.vit.encoder.layer)
        self.gamma = gamma

        # Multiscale Fusion
        self.mvit_encoder = ViTEncoder(self.vit.config)
        self.mvit_attention = nn.MultiheadAttention(embed_dim=self.hidden_size, num_heads=8)
        
        # Broad Attention Mechanism
        self.broad_attention = BroadAttention(hidden_size=self.hidden_size, num_layers=self.num_layers)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(self.hidden_size * 2, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, pixel_values):
        outputs = self.vit(pixel_values, output_hidden_states=True)
        hidden_states = outputs.hidden_states
        deep_features = hidden_states[-1][:, 0, :]
        queries = [layer[:, 0, :].unsqueeze(1) for layer in hidden_states]
        broad_features = self.broad_attention(queries, queries, queries)

        # MVIT Feature Extraction
        mvit_outputs = self.mvit_encoder(hidden_states[-1])
        mvit_features = mvit_outputs.last_hidden_state[:, 0, :]

        # Combine Features
        combined_features = torch.cat((deep_features, self.gamma * broad_features + mvit_features), dim=1)
        logits = self.classifier(combined_features)
        return logits

# %%
# Training function without plotting
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        train_preds, train_targets = [], []

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            train_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            train_targets.extend(labels.cpu().numpy())

        train_loss /= len(train_loader.dataset)
        train_accuracy = accuracy_score(train_targets, train_preds)

        model.eval()
        val_loss = 0.0
        val_preds, val_targets = [], []

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
                val_targets.extend(labels.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        val_accuracy = accuracy_score(val_targets, val_preds)

        # Collect losses and accuracies for plotting later
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)

        # Print out the progress of training
        print(f"Epoch {epoch + 1}/{epochs}: Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
# Evaluation function
def evaluate_model(model, test_loader):
    model.eval()
    test_preds, test_targets = [], []
    tn, fp, fn, tp = 0, 0, 0, 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)

            test_preds.extend(preds.cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

            # Calculate confusion matrix components for specificity
            for true, pred in zip(labels.cpu().numpy(), preds.cpu().numpy()):
                if true == 0 and pred == 0:
                    tn += 1
                elif true == 0 and pred == 1:
                    fp += 1
                elif true == 1 and pred == 0:
                    fn += 1
                elif true == 1 and pred == 1:
                    tp += 1

    # Precision, recall, f1 score, and accuracy
    precision = precision_score(test_targets, test_preds, average='weighted')
    recall = recall_score(test_targets, test_preds, average='weighted')
    f1 = f1_score(test_targets, test_preds, average='weighted')
    accuracy = accuracy_score(test_targets, test_preds)

    # Specificity
    specificity = tn / (tn + fp)

    # Classification Report
    report = classification_report(test_targets, test_preds, target_names=subfolders)
    print(report)

    return accuracy, precision, recall, f1, specificity

# 5-Fold Cross-Validation loop
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_results = []
fold_specificity = []

# Lists to store the overall metrics across all folds for plotting
all_train_losses = []
all_val_losses = []
all_train_accuracies = []
all_val_accuracies = []

for fold, (train_indices, val_indices) in enumerate(kf.split(dataset)):
    print(f"\nFold {fold + 1}")
    
    # Reset lists at the start of each fold
    train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []
    
    # Prepare the data loaders for the current fold
    train_subset = Subset(dataset, train_indices)
    val_subset = Subset(dataset, val_indices)

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # Initialize the model
    model = B2MVITNet("google/vit-base-patch16-224-in21k", num_classes=2, gamma=gamma).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Train the model
    train_model(model, train_loader, val_loader, criterion, optimizer, epochs)

    # Collect results for plotting later
    all_train_losses.extend(train_losses)
    all_val_losses.extend(val_losses)
    all_train_accuracies.extend(train_accuracies)
    all_val_accuracies.extend(val_accuracies)

    # Evaluate the model
    accuracy, precision, recall, f1, specificity = evaluate_model(model, val_loader)
    print(f"Fold {fold + 1} - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}, Specificity: {specificity:.4f}")
    fold_results.append((accuracy, precision, recall, f1))
    fold_specificity.append(specificity)

# Average Results
average_results = np.mean(fold_results, axis=0)
average_specificity = np.mean(fold_specificity)

print("\n5-Fold Cross-Validation Results:")
print(f"Average Accuracy: {average_results[0]:.4f}")
print(f"Average Precision: {average_results[1]:.4f}")
print(f"Average Recall: {average_results[2]:.4f}")
print(f"Average F1 Score: {average_results[3]:.4f}")
print(f"Average Specificity: {average_specificity:.4f}")

# Plotting the Loss vs Accuracy curve after all folds
plt.figure(figsize=(12, 6))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(range(epochs * 5), all_train_losses, label="Train Loss")
plt.plot(range(epochs * 5), all_val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(range(epochs * 5), all_train_accuracies, label="Train Accuracy")
plt.plot(range(epochs * 5), all_val_accuracies, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()
# Out:
# Fold 1
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# `ViTSdpaAttention` is used but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# Epoch 1/30: Train Loss: 0.4252, Train Accuracy: 0.8433, Val Loss: 0.1721, Val Accuracy: 0.9343
# Epoch 2/30: Train Loss: 0.1242, Train Accuracy: 0.9577, Val Loss: 0.2343, Val Accuracy: 0.9531
# Epoch 3/30: Train Loss: 0.0913, Train Accuracy: 0.9753, Val Loss: 0.1149, Val Accuracy: 0.9671
# Epoch 4/30: Train Loss: 0.0710, Train Accuracy: 0.9761, Val Loss: 0.1006, Val Accuracy: 0.9750
# Epoch 5/30: Train Loss: 0.0616, Train Accuracy: 0.9851, Val Loss: 0.0805, Val Accuracy: 0.9812
# Epoch 6/30: Train Loss: 0.0461, Train Accuracy: 0.9863, Val Loss: 0.0684, Val Accuracy: 0.9844
# Epoch 7/30: Train Loss: 0.0395, Train Accuracy: 0.9898, Val Loss: 0.0280, Val Accuracy: 0.9922
# Epoch 8/30: Train Loss: 0.0442, Train Accuracy: 0.9894, Val Loss: 0.0317, Val Accuracy: 0.9906
# Epoch 9/30: Train Loss: 0.0366, Train Accuracy: 0.9933, Val Loss: 0.0511, Val Accuracy: 0.9890
# Epoch 10/30: Train Loss: 0.0314, Train Accuracy: 0.9926, Val Loss: 0.0406, Val Accuracy: 0.9859
# Epoch 11/30: Train Loss: 0.0236, Train Accuracy: 0.9949, Val Loss: 0.1229, Val Accuracy: 0.9781
# Epoch 12/30: Train Loss: 0.0019, Train Accuracy: 0.9992, Val Loss: 0.0858, Val Accuracy: 0.9875
# Epoch 13/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0922, Val Accuracy: 0.9875
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0955, Val Accuracy: 0.9875
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0954, Val Accuracy: 0.9875
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0972, Val Accuracy: 0.9875
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0998, Val Accuracy: 0.9859
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1009, Val Accuracy: 0.9859
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1024, Val Accuracy: 0.9859
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1042, Val Accuracy: 0.9859
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1059, Val Accuracy: 0.9875
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1073, Val Accuracy: 0.9875
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1081, Val Accuracy: 0.9859
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1100, Val Accuracy: 0.9875
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1111, Val Accuracy: 0.9859
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1119, Val Accuracy: 0.9875
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1138, Val Accuracy: 0.9875
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1149, Val Accuracy: 0.9875
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1152, Val Accuracy: 0.9875
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.1160, Val Accuracy: 0.9875
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.98      0.99       303
#    Others_augmented       0.98      1.00      0.99       336
#
#            accuracy                           0.99       639
#           macro avg       0.99      0.99      0.99       639
#        weighted avg       0.99      0.99      0.99       639
#
# Fold 1 - Accuracy: 0.9875, Precision: 0.9876, Recall: 0.9875, F1 Score: 0.9875, Specificity: 0.9769
#
# Fold 2
# Epoch 1/30: Train Loss: 0.4995, Train Accuracy: 0.8061, Val Loss: 0.4252, Val Accuracy: 0.7700
# Epoch 2/30: Train Loss: 0.1471, Train Accuracy: 0.9499, Val Loss: 0.1023, Val Accuracy: 0.9703
# Epoch 3/30: Train Loss: 0.0711, Train Accuracy: 0.9749, Val Loss: 0.0443, Val Accuracy: 0.9859
# Epoch 4/30: Train Loss: 0.0707, Train Accuracy: 0.9796, Val Loss: 0.0982, Val Accuracy: 0.9640
# Epoch 5/30: Train Loss: 0.0333, Train Accuracy: 0.9886, Val Loss: 0.0710, Val Accuracy: 0.9797
# Epoch 6/30: Train Loss: 0.0764, Train Accuracy: 0.9781, Val Loss: 0.0547, Val Accuracy: 0.9781
# Epoch 7/30: Train Loss: 0.0100, Train Accuracy: 0.9973, Val Loss: 0.0591, Val Accuracy: 0.9859
# Epoch 8/30: Train Loss: 0.0065, Train Accuracy: 0.9980, Val Loss: 0.0555, Val Accuracy: 0.9812
# Epoch 9/30: Train Loss: 0.0171, Train Accuracy: 0.9961, Val Loss: 0.1800, Val Accuracy: 0.9405
# Epoch 10/30: Train Loss: 0.0692, Train Accuracy: 0.9808, Val Loss: 0.0556, Val Accuracy: 0.9828
# Epoch 11/30: Train Loss: 0.0987, Train Accuracy: 0.9687, Val Loss: 0.9412, Val Accuracy: 0.8044
# Epoch 12/30: Train Loss: 0.0478, Train Accuracy: 0.9863, Val Loss: 0.0269, Val Accuracy: 0.9922
# Epoch 13/30: Train Loss: 0.0004, Train Accuracy: 1.0000, Val Loss: 0.0466, Val Accuracy: 0.9906
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0390, Val Accuracy: 0.9937
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0371, Val Accuracy: 0.9953
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0346, Val Accuracy: 0.9953
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0356, Val Accuracy: 0.9953
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0350, Val Accuracy: 0.9953
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0359, Val Accuracy: 0.9953
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0365, Val Accuracy: 0.9953
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0364, Val Accuracy: 0.9953
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0364, Val Accuracy: 0.9953
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0367, Val Accuracy: 0.9953
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0369, Val Accuracy: 0.9953
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0377, Val Accuracy: 0.9953
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0379, Val Accuracy: 0.9953
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0383, Val Accuracy: 0.9953
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0387, Val Accuracy: 0.9953
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0387, Val Accuracy: 0.9953
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0389, Val Accuracy: 0.9953
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.99      0.99       289
#    Others_augmented       0.99      1.00      1.00       350
#
#            accuracy                           1.00       639
#           macro avg       1.00      0.99      1.00       639
#        weighted avg       1.00      1.00      1.00       639
#
# Fold 2 - Accuracy: 0.9953, Precision: 0.9953, Recall: 0.9953, F1 Score: 0.9953, Specificity: 0.9896
#
# Fold 3
# Epoch 1/30: Train Loss: 0.4608, Train Accuracy: 0.8277, Val Loss: 0.1560, Val Accuracy: 0.9436
# Epoch 2/30: Train Loss: 0.1211, Train Accuracy: 0.9605, Val Loss: 0.4185, Val Accuracy: 0.9248
# Epoch 3/30: Train Loss: 0.1154, Train Accuracy: 0.9612, Val Loss: 0.2720, Val Accuracy: 0.9483
# Epoch 4/30: Train Loss: 0.0725, Train Accuracy: 0.9777, Val Loss: 0.0547, Val Accuracy: 0.9875
# Epoch 5/30: Train Loss: 0.0253, Train Accuracy: 0.9922, Val Loss: 0.1066, Val Accuracy: 0.9890
# Epoch 6/30: Train Loss: 0.0260, Train Accuracy: 0.9930, Val Loss: 0.0603, Val Accuracy: 0.9812
# Epoch 7/30: Train Loss: 0.0014, Train Accuracy: 1.0000, Val Loss: 0.0319, Val Accuracy: 0.9922
# Epoch 8/30: Train Loss: 0.0007, Train Accuracy: 1.0000, Val Loss: 0.0880, Val Accuracy: 0.9781
# Epoch 9/30: Train Loss: 0.1239, Train Accuracy: 0.9612, Val Loss: 0.0527, Val Accuracy: 0.9843
# Epoch 10/30: Train Loss: 0.0897, Train Accuracy: 0.9742, Val Loss: 0.0472, Val Accuracy: 0.9859
# Epoch 11/30: Train Loss: 0.0108, Train Accuracy: 0.9980, Val Loss: 0.0374, Val Accuracy: 0.9922
# Epoch 12/30: Train Loss: 0.0003, Train Accuracy: 1.0000, Val Loss: 0.0375, Val Accuracy: 0.9906
# Epoch 13/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0409, Val Accuracy: 0.9906
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0430, Val Accuracy: 0.9906
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0451, Val Accuracy: 0.9906
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0446, Val Accuracy: 0.9906
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0468, Val Accuracy: 0.9906
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0479, Val Accuracy: 0.9906
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0454, Val Accuracy: 0.9906
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0472, Val Accuracy: 0.9906
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0478, Val Accuracy: 0.9906
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0501, Val Accuracy: 0.9906
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0519, Val Accuracy: 0.9906
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0527, Val Accuracy: 0.9906
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0536, Val Accuracy: 0.9906
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0543, Val Accuracy: 0.9906
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0538, Val Accuracy: 0.9906
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0533, Val Accuracy: 0.9906
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0541, Val Accuracy: 0.9906
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0552, Val Accuracy: 0.9906
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      0.98      0.99       275
#    Others_augmented       0.99      1.00      0.99       363
#
#            accuracy                           0.99       638
#           macro avg       0.99      0.99      0.99       638
#        weighted avg       0.99      0.99      0.99       638
#
# Fold 3 - Accuracy: 0.9906, Precision: 0.9907, Recall: 0.9906, F1 Score: 0.9906, Specificity: 0.9818
#
# Fold 4
# Epoch 1/30: Train Loss: 0.4478, Train Accuracy: 0.8281, Val Loss: 0.4609, Val Accuracy: 0.8683
# Epoch 2/30: Train Loss: 0.1238, Train Accuracy: 0.9581, Val Loss: 0.0902, Val Accuracy: 0.9655
# Epoch 3/30: Train Loss: 0.0781, Train Accuracy: 0.9749, Val Loss: 0.0819, Val Accuracy: 0.9687
# Epoch 4/30: Train Loss: 0.0526, Train Accuracy: 0.9820, Val Loss: 0.0343, Val Accuracy: 0.9890
# Epoch 5/30: Train Loss: 0.0659, Train Accuracy: 0.9820, Val Loss: 0.1774, Val Accuracy: 0.9561
# Epoch 6/30: Train Loss: 0.0545, Train Accuracy: 0.9847, Val Loss: 0.0227, Val Accuracy: 0.9922
# Epoch 7/30: Train Loss: 0.0426, Train Accuracy: 0.9859, Val Loss: 0.0920, Val Accuracy: 0.9718
# Epoch 8/30: Train Loss: 0.0071, Train Accuracy: 0.9969, Val Loss: 0.0553, Val Accuracy: 0.9875
# Epoch 9/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0484, Val Accuracy: 0.9890
# Epoch 10/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0501, Val Accuracy: 0.9890
# Epoch 11/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0509, Val Accuracy: 0.9890
# Epoch 12/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0495, Val Accuracy: 0.9890
# Epoch 13/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0504, Val Accuracy: 0.9890
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0514, Val Accuracy: 0.9890
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0533, Val Accuracy: 0.9890
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0536, Val Accuracy: 0.9890
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0538, Val Accuracy: 0.9890
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0533, Val Accuracy: 0.9890
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0541, Val Accuracy: 0.9890
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0558, Val Accuracy: 0.9890
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0558, Val Accuracy: 0.9890
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0544, Val Accuracy: 0.9890
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0551, Val Accuracy: 0.9890
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0563, Val Accuracy: 0.9890
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0558, Val Accuracy: 0.9890
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0559, Val Accuracy: 0.9890
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0558, Val Accuracy: 0.9890
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0549, Val Accuracy: 0.9890
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0553, Val Accuracy: 0.9890
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0557, Val Accuracy: 0.9890
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       0.99      0.98      0.99       282
#    Others_augmented       0.99      0.99      0.99       356
#
#            accuracy                           0.99       638
#           macro avg       0.99      0.99      0.99       638
#        weighted avg       0.99      0.99      0.99       638
#
# Fold 4 - Accuracy: 0.9890, Precision: 0.9891, Recall: 0.9890, F1 Score: 0.9890, Specificity: 0.9823
#
# Fold 5
# Epoch 1/30: Train Loss: 0.4639, Train Accuracy: 0.8175, Val Loss: 0.1612, Val Accuracy: 0.9483
# Epoch 2/30: Train Loss: 0.1391, Train Accuracy: 0.9558, Val Loss: 0.0541, Val Accuracy: 0.9781
# Epoch 3/30: Train Loss: 0.0649, Train Accuracy: 0.9781, Val Loss: 0.0892, Val Accuracy: 0.9702
# Epoch 4/30: Train Loss: 0.0787, Train Accuracy: 0.9749, Val Loss: 0.3537, Val Accuracy: 0.9201
# Epoch 5/30: Train Loss: 0.0335, Train Accuracy: 0.9910, Val Loss: 0.2468, Val Accuracy: 0.9404
# Epoch 6/30: Train Loss: 0.0338, Train Accuracy: 0.9890, Val Loss: 0.1133, Val Accuracy: 0.9655
# Epoch 7/30: Train Loss: 0.0614, Train Accuracy: 0.9847, Val Loss: 0.1023, Val Accuracy: 0.9655
# Epoch 8/30: Train Loss: 0.0594, Train Accuracy: 0.9843, Val Loss: 0.0541, Val Accuracy: 0.9796
# Epoch 9/30: Train Loss: 0.0374, Train Accuracy: 0.9886, Val Loss: 0.0603, Val Accuracy: 0.9843
# Epoch 10/30: Train Loss: 0.0439, Train Accuracy: 0.9855, Val Loss: 0.0584, Val Accuracy: 0.9765
# Epoch 11/30: Train Loss: 0.0345, Train Accuracy: 0.9945, Val Loss: 0.0340, Val Accuracy: 0.9859
# Epoch 12/30: Train Loss: 0.0123, Train Accuracy: 0.9953, Val Loss: 0.0521, Val Accuracy: 0.9859
# Epoch 13/30: Train Loss: 0.0082, Train Accuracy: 0.9992, Val Loss: 0.0138, Val Accuracy: 0.9953
# Epoch 14/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0111, Val Accuracy: 0.9969
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0113, Val Accuracy: 0.9969
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0113, Val Accuracy: 0.9969
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0112, Val Accuracy: 0.9969
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0112, Val Accuracy: 0.9969
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0114, Val Accuracy: 0.9969
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0112, Val Accuracy: 0.9969
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0116, Val Accuracy: 0.9969
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0117, Val Accuracy: 0.9969
#                      precision    recall  f1-score   support
#
# Monkeypox_augmented       1.00      1.00      1.00       279
#    Others_augmented       1.00      1.00      1.00       359
#
#            accuracy                           1.00       638
#           macro avg       1.00      1.00      1.00       638
#        weighted avg       1.00      1.00      1.00       638
#
# Fold 5 - Accuracy: 0.9969, Precision: 0.9969, Recall: 0.9969, F1 Score: 0.9969, Specificity: 0.9964
#
# 5-Fold Cross-Validation Results:
# Average Accuracy: 0.9919
# Average Precision: 0.9919
# Average Recall: 0.9919
# Average F1 Score: 0.9919
# Average Specificity: 0.9854

# %%
from sklearn.metrics import roc_curve, auc

def plot_roc_curve(model, test_loader):
    model.eval()
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probs = torch.nn.functional.softmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # Convert lists to numpy arrays
    all_labels = np.array(all_labels)
    all_probs = np.array(all_probs)

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(all_labels, all_probs[:, 1])  # Assuming binary classification (class 1 is positive)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrix(model, test_loader):
    model.eval()
    all_labels = []
    all_preds = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    cm = confusion_matrix(all_labels, all_preds)

    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=subfolders, yticklabels=subfolders)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
plot_roc_curve(model, val_loader)  # For ROC AUC curve
plot_confusion_matrix(model, val_loader)  # For Confusion Matrix

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math
from torchvision import transforms
from PIL import Image
from transformers import ViTForImageClassification

def generate_vit_gradcam(model, image, target_class, device):
    model.eval()

    # Hook to capture activations and gradients
    activations, gradients = None, None

    def forward_hook(module, input, output):
        nonlocal activations
        activations = output  # Capture the output activations

    def backward_hook(module, grad_in, grad_out):
        nonlocal gradients
        gradients = grad_out[0]  # Capture the gradients

    # Register hooks on the last encoder block's output
    last_layer = model.vit.encoder.layer[-1].output
    forward_hook_handle = last_layer.register_forward_hook(forward_hook)
    backward_hook_handle = last_layer.register_backward_hook(backward_hook)

    # Forward pass
    image = image.to(device)
    logits = model(image).logits
    loss = logits[0, target_class]
    loss.backward()

    # Compute Grad-CAM
    pooled_gradients = torch.mean(gradients, dim=0)  # Global average pooling over batch
    activations = activations[0]  # Remove batch dimension

    # Remove the class token (first token)
    activations = activations[1:]  # Removing the class token (index 0)
    
    # Compute the Grad-CAM map
    gradcam_map = torch.einsum("ij,kj->i", [activations, pooled_gradients])  # Matrix multiplication

    # Reshape the Grad-CAM map to the grid size (only patch tokens)
    num_patches = gradcam_map.shape[0]
    grid_size = int(math.sqrt(num_patches))
    gradcam_map = gradcam_map.view(grid_size, grid_size).cpu().detach().numpy()

    # Normalize Grad-CAM
    gradcam_map = np.maximum(gradcam_map, 0)  # Apply ReLU to remove negative values
    gradcam_map -= gradcam_map.min()  # Normalize to [0, 1]
    gradcam_map /= gradcam_map.max()
    gradcam_map = cv2.resize(gradcam_map, (224, 224))  # Resize to original image size

    # De-normalize the input image
    original_image = image.squeeze(0).cpu().detach().numpy().transpose(1, 2, 0)
    original_image = original_image * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406]
    original_image = np.clip(original_image, 0, 1)

    # Plot Grad-CAM overlay
    plt.imshow(original_image)
    plt.imshow(gradcam_map, alpha=0.5, cmap='jet')
    plt.title(f"Grad-CAM for class {target_class}")
    plt.axis("off")
    plt.show()

    # Remove hooks
    forward_hook_handle.remove()
    backward_hook_handle.remove()

# Load the model and preprocess the image
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k").to(device)

image_path = "/kaggle/input/monkeypox-skin-lesion-dataset/Augmented Images/Augmented Images/Monkeypox_augmented/M01_02_01.jpg"
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Prepare the input image
sample_image = Image.open(image_path).convert("RGB")
sample_image_tensor = transform(sample_image).unsqueeze(0)

# Generate Grad-CAM
generate_vit_gradcam(model, sample_image_tensor, target_class=1, device=device)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1827: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
